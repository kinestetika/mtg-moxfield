# %%
budget_decklist='''0	5	0	Ad Nauseam
1	0	1	Ancient Tomb
1	1	0	Animate Dead
1	2	0	Arcane Signet
1	0	0	Arid Mesa
1	0	0	Blood Crypt
1	0	0	Bloodstained Mire
1	2	0	Boros Signet
1	6	0	Burning-Rune Demon
1	1	3	Burnt Offering
1	2	3	Cabal Ritual
1	0	0	Cavern of Souls
1	1	0	Children of Korlis
1	0	1	Chrome Mox
1	0	0	Command Tower
1	1	3	Culling the Weak
1	1	0	Firestorm
1	1	2	Dark Ritual
1	2	0	Dauthi Voidwalker
1	3	0	Deflecting Swat
1	2	0	Demonic Tutor
1	2	0	Diabolic Intent
1	2	2	Dockside Extortionist
1	5	0	Doom Whisperer
1	3	0	Dark Deal
1	1	0	Dragon's Rage Channeler
1	3	0	Dualcaster Mage
1	0	0	Emergence Zone
1	1	0	Enlightened Tutor
1	1	0	Entomb
1	1	0	Ephemerate
1	1	0	Malakir Rebirth
1	0	0	Exotic Orchard
1	1	0	Faithless Looting
1	2	0	Fellwar Stone
1	0	0	Flooded Strand
1	0	0	Forbidden Orchard
1	1	0	Gamble
1	0	0	Gemstone Caverns
1	0	0	Godless Shrine
1	2	0	Grand Abolisher
1	3	3	Jeska's Will
1	0	0	Jeweled Lotus
0	4	0	Kaalia of the Vast
1	1	0	Insolent Neonate
1	2	0	Leonin Relic-Warder
1	0	1	Lotus Petal
1	0	0	Luxury Suite
1	0	0	Mana Confluence
1	0	2	Mana Crypt
1	1	2	Mana Vault
1	0	0	Marsh Flats
1	2	0	Mausoleum Secrets
1	3	0	Mayhem Devil
1	0	1	Mox Amber
1	0	1	Mox Opal
1	3	0	Necromancy
1	3	0	Necropotence
1	3	0	Opposition Agent
1	1	0	Orim's Chant
1	2	0	Orzhov Signet
1	7	0	Peer into the Abyss
1	0	0	Plains
1	0	0	Polluted Delta
1	3	0	Praetor's Grasp
1	2	0	Priest of Fell Rites
1	1	0	Pyroblast
1	1	0	Ragavan, Nimble Pilferer
1	1	3	Rain of Filth
1	2	0	Rakdos Signet
1	3	0	Ranger-Captain of Eos
1	8	0	Razaketh, the Foulblooded
1	1	0	Reanimate
1	1	0	Red Elemental Blast
1	1	1	Rite of Flame
1	7	0	Rune-Scarred Demon
1	0	0	Sacred Foundry
1	0	0	Scalding Tarn
1	3	0	Sevinne's Reclamation
1	1	0	Silence
1	3	1	Simian Spirit Guide
1	1	0	Skirk Prospector
1	3	0	Skyclave Apparition
1	0	0	Snow-Covered Swamp
1	1	1	Sol Ring
1	0	0	Spectator Seating
1	0	0	Spire of Industry
1	0	0	Swamp
1	2	0	Tainted Pact
1	0	0	Tarnished Citadel
1	2	0	Twinflame
1	0	0	Underworld Breach
1	1	0	Vampiric Tutor
1	0	0	Vault of Champions
1	0	0	Verdant Catacombs
1	8	0	Vilis, Broker of Blood
1	3	0	Wheel of Misfortune
1	0	0	Windswept Heath
1	2	0	Wishclaw Talisman
1	0	0	Wooded Foothills'''

# %%
budget_deck = [l.split('\t') for l in budget_decklist.split('\n')]
print(budget_deck)
# Out:
# [['0', '5', '0', 'Ad Nauseam'], ['1', '0', '1', 'Ancient Tomb'], ['1', '1', '0', 'Animate Dead'], ['1', '2', '0', 'Arcane Signet'], ['1', '0', '0', 'Arid Mesa'], ['1', '0', '0', 'Blood Crypt'], ['1', '0', '0', 'Bloodstained Mire'], ['1', '2', '0', 'Boros Signet'], ['1', '6', '0', 'Burning-Rune Demon'], ['1', '1', '3', 'Burnt Offering'], ['1', '2', '3', 'Cabal Ritual'], ['1', '0', '0', 'Cavern of Souls'], ['1', '1', '0', 'Children of Korlis'], ['1', '0', '1', 'Chrome Mox'], ['1', '0', '0', 'Command Tower'], ['1', '1', '3', 'Culling the Weak'], ['1', '1', '0', 'Firestorm'], ['1', '1', '2', 'Dark Ritual'], ['1', '2', '0', 'Dauthi Voidwalker'], ['1', '3', '0', 'Deflecting Swat'], ['1', '2', '0', 'Demonic Tutor'], ['1', '2', '0', 'Diabolic Intent'], ['1', '2', '2', 'Dockside Extortionist'], ['1', '5', '0', 'Doom Whisperer'], ['1', '3', '0', 'Dark Deal'], ['1', '1', '0', "Dragon's Rage Channeler"], ['1', '3', '0', 'Dualcaster Mage'], ['1', '0', '0', 'Emergence Zone'], ['1', '1', '0', 'Enli
# ...

# %%
baddog_decklist='''0	5	0	Ad Nauseam
1	0	1	Ancient Tomb
1	2	0	Animate Dead
1	2	0	Arcane Signet
1	0	0	Arid Mesa
1	0	0	Badlands
1	0	0	Blood Crypt
1	0	0	Bloodstained Mire
1	1	3	Burnt Offering
1	2	3	Cabal Ritual
1	0	0	Cavern of Souls
1	1	0	Children of Korlis
1	0	1	Chrome Mox
1	0	1	City of Traitors
1	0	0	Command Tower
1	1	3	Culling the Weak
1	2	0	Damn
1	1	2	Dark Ritual
1	2	0	Dauthi Voidwalker
1	3	0	Deflecting Swat
1	2	0	Demonic Tutor
1	2	0	Diabolic Intent
1	2	2	Dockside Extortionist
1	5	0	Doom Whisperer
1	1	0	Dragon's Rage Channeler
1	3	0	Dualcaster Mage
1	0	0	Emergence Zone
1	1	0	Enlightened Tutor
1	1	0	Entomb
1	1	0	Ephemerate
1	1	0	Esper Sentinel
1	0	0	Exotic Orchard
1	1	0	Faithless Looting
1	2	0	Fellwar Stone
1	0	0	Flooded Strand
1	1	0	Gamble
1	0	0	Gemstone Caverns
1	0	0	Godless Shrine
1	2	0	Grand Abolisher
1	2	1	Grim Monolith
1	1	0	Imperial Seal
1	3	0	Jeska's Will
1	0	0	Jeweled Lotus
0	4	0	Kaalia of the Vast
1	1	0	Kuldotha Rebirth
1	2	0	Leonin Relic-Warder
1	0	3	Lion's Eye Diamond
1	0	1	Lotus Petal
1	0	0	Luxury Suite
1	0	2	Mana Crypt
1	1	2	Mana Vault
1	0	0	Marsh Flats
1	2	0	Mausoleum Secrets
1	3	0	Mayhem Devil
1	0	1	Mox Diamond
1	0	1	Mox Opal
1	3	0	Necromancy
1	3	0	Necropotence
1	3	0	Opposition Agent
1	1	0	Orim's Chant
1	7	0	Peer into the Abyss
1	0	0	Plateau
1	0	0	Polluted Delta
1	3	0	Praetor's Grasp
1	1	0	Pyroblast
1	1	0	Ragavan, Nimble Pilferer
1	1	3	Rain of Filth
1	2	0	Rakdos Signet
1	3	0	Ranger-Captain of Eos
1	8	0	Razaketh, the Foulblooded
1	1	0	Reanimate
1	1	0	Red Elemental Blast
1	1	1	Rite of Flame
1	6	0	Rune-Scarred Demon
1	0	0	Sacred Foundry
1	0	0	Scalding Tarn
1	0	0	Scrubland
1	3	0	Sevinne's Reclamation
1	1	0	Silence
1	3	1	Simian Spirit Guide
1	1	0	Skirk Prospector
1	3	0	Skyclave Apparition
1	0	0	Snow-Covered Swamp
1	1	1	Sol Ring
1	0	0	Spectator Seating
1	0	0	Spire of Industry
1	0	0	Swamp
1	2	0	Tainted Pact
1	2	0	Talisman of Indulgence
1	2	0	Twinflame
1	2	0	Underworld Breach
1	1	0	Vampiric Tutor
1	0	0	Vault of Champions
1	0	0	Verdant Catacombs
1	8	0	Vilis, Broker of Blood
1	3	0	Wheel of Fortune
1	3	0	Wheel of Misfortune
1	0	0	Windswept Heath
1	2	0	Wishclaw Talisman
1	0	0	Wooded Foothills'''

# %%
baddog_deck = [l.split('\t') for l in baddog_decklist.split('\n')]
print(baddog_deck)
# Out:
# [['0', '5', '0', 'Ad Nauseam'], ['1', '0', '1', 'Ancient Tomb'], ['1', '2', '0', 'Animate Dead'], ['1', '2', '0', 'Arcane Signet'], ['1', '0', '0', 'Arid Mesa'], ['1', '0', '0', 'Badlands'], ['1', '0', '0', 'Blood Crypt'], ['1', '0', '0', 'Bloodstained Mire'], ['1', '1', '3', 'Burnt Offering'], ['1', '2', '3', 'Cabal Ritual'], ['1', '0', '0', 'Cavern of Souls'], ['1', '1', '0', 'Children of Korlis'], ['1', '0', '1', 'Chrome Mox'], ['1', '0', '1', 'City of Traitors'], ['1', '0', '0', 'Command Tower'], ['1', '1', '3', 'Culling the Weak'], ['1', '2', '0', 'Damn'], ['1', '1', '2', 'Dark Ritual'], ['1', '2', '0', 'Dauthi Voidwalker'], ['1', '3', '0', 'Deflecting Swat'], ['1', '2', '0', 'Demonic Tutor'], ['1', '2', '0', 'Diabolic Intent'], ['1', '2', '2', 'Dockside Extortionist'], ['1', '5', '0', 'Doom Whisperer'], ['1', '1', '0', "Dragon's Rage Channeler"], ['1', '3', '0', 'Dualcaster Mage'], ['1', '0', '0', 'Emergence Zone'], ['1', '1', '0', 'Enlightened Tutor'], ['1', '1', '0', 'Entomb'
# ...

# %%
import random

def ad_naus(deck, life_lost_threshold=30):
    life_lost = 0
    fast_mana_total = 0
    total_cards = 0
    deck_copy = deck.copy()
    while (life_lost < life_lost_threshold):
        card_number = random.randint(0,len(deck_copy)-1)
        card = deck_copy[card_number]
        del deck_copy[card_number]
        if not card[0]:
            continue
        total_cards += 1
        life_lost += int(card[1])
        fast_mana_total += int(card[2])
    return [total_cards, fast_mana_total]

print(ad_naus(budget_deck, 30))
# Out:
# [16, 9]

# %%
import numpy as np
import pandas as pd

benchmarking = pd.DataFrame(columns=['baddog # cards', 'baddog fast mana', 'budget # cards', 'budget fast mana'])


for i in range (10000):
    benchmarking.loc[len(benchmarking)] = np.concatenate((ad_naus(baddog_deck), 
                                                         ad_naus(budget_deck)))
    
benchmarking.describe()
# Out:
#         baddog # cards  baddog fast mana  budget # cards  budget fast mana
# count            10000             10000           10000             10000
# unique              33                25              35                22
# top                 20                 5              19                 5
# freq               860              1128             837              1135

# %%
# %matplotlib inline
import matplotlib.pyplot as plot

# %%
fig1, f1_axes = plot.subplots(2, 2, figsize=(8,8))
fig1.tight_layout(h_pad=4, w_pad=8)

f1_axes[0][0].set_title('baddog')
f1_axes[0][0].set_xlabel('# cards')
f1_axes[0][0].set_ylabel('Ad Naus plays')
f1_axes[0][0].hist(benchmarking['baddog # cards'], bins=[0,5,10,15,20,25,30,35,40])
f1_axes[0][0].set_ylim([0,4000])
f1_axes[0][1].set_title('budget')
f1_axes[0][1].set_xlabel('# cards')
f1_axes[0][1].set_ylabel('Ad Naus plays')
f1_axes[0][1].hist(benchmarking['budget # cards'], bins=[0,5,10,15,20,25,30,35,40])
f1_axes[0][1].set_ylim([0,4000])

f1_axes[1][0].set_title('baddog')
f1_axes[1][0].set_xlabel('fast mana')
f1_axes[1][0].set_ylabel('Ad Naus plays')
f1_axes[1][0].hist(benchmarking['baddog fast mana'], bins=[0,2,4,6,8,10,12,14,16], color='k')
f1_axes[1][1].set_title('budget')
f1_axes[1][1].set_xlabel('fast mana')
f1_axes[1][1].set_ylabel('Ad Naus plays')
f1_axes[1][1].hist(benchmarking['budget fast mana'], bins=[0,2,4,6,8,10,12,14,16], color='k')

print(f'baddog average # of cards: {benchmarking["baddog # cards"].mean():.1f}') 
print(f'budget average # of cards: {benchmarking["budget # cards"].mean():.1f}')
print(f'baddog average fast mana: {benchmarking["baddog fast mana"].mean():.1f}') 
print(f'budget average fast mana: {benchmarking["budget fast mana"].mean():.1f}')
# Out:
# baddog average # of cards: 20.8
# budget average # of cards: 20.3
# baddog average fast mana: 6.8
# budget average fast mana: 6.3

# %%
combos = [['Dualcaster Mage', 'Twinflame'], ['Praetor\'s Grasp', 'Tainted Pact'], 'Razaketh, the Foulblooded']

tutors = ['Demonic Tutor', 'Diabolic Intent', 'Wishclaw Talisman', 'Vampiric Tutor', 'Imperial Seal', 'Gamble']
